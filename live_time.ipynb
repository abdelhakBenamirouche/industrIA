# %%
from keras.preprocessing import image
from tensorflow.keras.utils import load_img, img_to_array

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
# from google.colab import files

import zipfile
import os

from tensorflow.keras.models import load_model
from keras.preprocessing import image
import numpy as np

# %%
model = load_model('model_pc.h5', compile=False)

# %%
# model.compile(optimizer = Adam(learning_rate = 0.0001), loss = 'categorical_crossentropy', metrics = 'accuracy')

# %%
class_names = {'RAM test': 1, 'Ventilateur': 2, 'Batterie': 0}

# %%
path = 'img2.png'
img = tf.keras.utils.load_img(path, target_size=(250,250, 3))
imgplot = plt.imshow(img)
x = tf.keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
predict = model.predict(images)
index = predict[0].argmax()

for key,value in class_names.items():
    if value == index:
        print(key)
# Out:
# 1/1 [==============================] - 0s 88ms/step
# Batterie

# %%
import numpy as np
import cv2
import pickle

width = 640
height = 480
threshold = 0.65  # MINIMUM PROBABILITY TO CLASSIFY
cameraNo = 0

# importing webcam footage
cap = cv2.VideoCapture(cameraNo)
cap.set(3, width)
cap.set(4, height)

# loading the training model
# pickle_in = open("C:/Users/Sakshee/model_trained.p", "rb")
# model = pickle.load(pickle_in)


def preProcessing(img):
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     img = cv2.equalizeHist(img)
    img = img / 255
    return img


while True:
    success, imgOriginal = cap.read()
    img = np.asarray(imgOriginal)
    img = cv2.resize(img, (250, 250))
    img = preProcessing(img)

#     cv2.imshow("Processsed Image", img)
#     img = img.reshape(1, 250, 250, 1)
    
    img = tf.keras.utils.load_img(path, target_size=(250,250, 3))
# imgplot = plt.imshow(img)
    x = tf.keras.utils.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    predict = model.predict(images)
    index = predict[0].argmax()

    for key,value in class_names.items():
        if value == index:
            print(key)
#             cv2.putText(img,"Class:"+str(key),(0,0),0.75,(0,0,255),2,cv2.LINE_AA)
#             cv2.putText(
#                       img = img,
#                       text = "Class:"+str(key),
#                       org = (200, 200),
#                       fontFace = cv2.FONT_HERSHEY_DUPLEX,
#                       fontScale = 3.0,
#                       color = (125, 246, 55),
#                       thickness = 3
#                     )
    
    
#     # making predictions
#     classIndex = int(model.predict_classes(img))
#     print(classIndex)
#     predictions = model.predict(img)
#     print(predictions)
#     probVal = np.amax(predictions)
#     print(classIndex, probVal)

#     if probVal > threshold:
#         cv2.putText(imgOriginal, str(classIndex) + " " + str(probVal), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 1)

    cv2.imshow("Original Image", imgOriginal)
    if cv2.waitKey(1) and 0xFF == ord('q'):
        break
# Out:
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 37ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 39ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 34ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 40ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 61ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 40ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 35ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 73ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 41ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 34ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 39ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 42ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 39ms/step
# Ventilateur
# 1/1 [==============================] - 0s 67ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 43ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 43ms/step
# Ventilateur
# 1/1 [==============================] - 0s 43ms/step
# Ventilateur
# 1/1 [==============================] - 0s 42ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 43ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 68ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 66ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 41ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 67ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 41ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 59ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 70ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 40ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 73ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 44ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 41ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 37ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 33ms/step
# Ventilateur
# 1/1 [==============================] - 0s 44ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 144ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 44ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 35ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 61ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 41ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 42ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 61ms/step
# Ventilateur
# 1/1 [==============================] - 0s 68ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 41ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 38ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 40ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 38ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 63ms/step
# Ventilateur
# 1/1 [==============================] - 0s 40ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 67ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 66ms/step
# Ventilateur
# 1/1 [==============================] - 0s 63ms/step
# Ventilateur
# 1/1 [==============================] - 0s 59ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 61ms/step
# Ventilateur
# 1/1 [==============================] - 0s 77ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 45ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 75ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 61ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 68ms/step
# Ventilateur
# 1/1 [==============================] - 0s 41ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 33ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 68ms/step
# Ventilateur
# 1/1 [==============================] - 0s 59ms/step
# Ventilateur
# 1/1 [==============================] - 0s 70ms/step
# Ventilateur
# 1/1 [==============================] - 0s 61ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 42ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 73ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 44ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 34ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 63ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 33ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 80ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 67ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 63ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 34ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 36ms/step
# Ventilateur
# 1/1 [==============================] - 0s 63ms/step
# Ventilateur
# 1/1 [==============================] - 0s 59ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 67ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 67ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 39ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 61ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 63ms/step
# Ventilateur
# 1/1 [==============================] - 0s 42ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 32ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 68ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 73ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 66ms/step
# Ventilateur
# 1/1 [==============================] - 0s 63ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 45ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 56ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 50ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 60ms/step
# Ventilateur
# 1/1 [==============================] - 0s 67ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 68ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 54ms/step
# Ventilateur
# 1/1 [==============================] - 0s 84ms/step
# Ventilateur
# 1/1 [==============================] - 0s 68ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 69ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 52ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 59ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 73ms/step
# Ventilateur
# 1/1 [==============================] - 0s 34ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 61ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 45ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 58ms/step
# Ventilateur
# 1/1 [==============================] - 0s 59ms/step
# Ventilateur
# 1/1 [==============================] - 0s 68ms/step
# Ventilateur
# 1/1 [==============================] - 0s 73ms/step
# Ventilateur
# 1/1 [==============================] - 0s 62ms/step
# Ventilateur
# 1/1 [==============================] - 0s 66ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 61ms/step
# Ventilateur
# 1/1 [==============================] - 0s 55ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 45ms/step
# Ventilateur
# 1/1 [==============================] - 0s 34ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 64ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 63ms/step
# Ventilateur
# 1/1 [==============================] - 0s 47ms/step
# Ventilateur
# 1/1 [==============================] - 0s 53ms/step
# Ventilateur
# 1/1 [==============================] - 0s 51ms/step
# Ventilateur
# 1/1 [==============================] - 0s 65ms/step
# Ventilateur
# 1/1 [==============================] - 0s 63ms/step
# Ventilateur
# 1/1 [==============================] - 0s 49ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 46ms/step
# Ventilateur
# 1/1 [==============================] - 0s 48ms/step
# Ventilateur
# 1/1 [==============================] - 0s 57ms/step
# Ventilateur
# 1/1 [==============================] - 0s 41ms/step
# Ventilateur
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [17], in <cell line: 27>()
#      24     return img
#      27 while True:
# ---> 28     success, imgOriginal = cap.read()
#      29     img = np.asarray(imgOriginal)
#      30     img = cv2.resize(img, (250, 250))
#
# KeyboardInterrupt:

# %%
pip install cvzone
# Out:
# Collecting cvzone
#   Downloading cvzone-1.5.6.tar.gz (12 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: opencv-python in c:\users\lenov\appdata\local\programs\python\python310\lib\site-packages (from cvzone) (4.5.5.64)
# Requirement already satisfied: numpy in c:\users\lenov\appdata\local\programs\python\python310\lib\site-packages (from cvzone) (1.22.3)
# Building wheels for collected packages: cvzone
#   Building wheel for cvzone (setup.py): started
#   Building wheel for cvzone (setup.py): finished with status 'done'
#   Created wheel for cvzone: filename=cvzone-1.5.6-py3-none-any.whl size=18768 sha256=fbf9b6a8e379fa7fdc08a4b7be57aa0845b164a839795b355ff486d5c7fc5d95
#   Stored in directory: c:\users\lenov\appdata\local\pip\cache\wheels\d8\85\f1\1756f9e009d280be742fb20dd5087c60c2f7f0279964934375
# Successfully built cvzone
# Installing collected packages: cvzone
# Successfully installed cvzone-1.5.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import cvzone
import cv2

# %%
from cvzone.ClassificationModule import Classifier

# %%
cap = cv2.VideoCapture(0)
myClassifier = Classifier('model_pc.h5','label.txt')
myClassifier.compile(optimizer = Adam(learning_rate = 0.0001), loss = 'categorical_crossentropy', metrics = 'accuracy')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 cap = cv2.VideoCapture(0)
# ----> 2 myClassifier = Classifier('model_pc.h5','label.txt')
#       3 myClassifier.compile(optimizer = Adam(learning_rate = 0.0001), loss = 'categorical_crossentropy', metrics = 'accuracy')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\cvzone\ClassificationModule.py:19, in Classifier.__init__(self, modelPath, labelsPath)
#      17 np.set_printoptions(suppress=True)
#      18 # Load the model
# ---> 19 self.model = tensorflow.keras.models.load_model(self.model_path)
#      21 # Create the array of the right shape to feed into the keras model
#      22 # The 'length' or number of images you can put into the array is
#      23 # determined by the first position in the shape tuple, in this case 1.
#      24 self.data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:94, in _BaseOptimizer._process_kwargs(self, kwargs)
#      90   logging.warning(
#      91       "%s is deprecated in `optimizer_experimental.Optimizer`"
#      92       ", please check the docstring for valid arguments.", k)
#      93 else:
# ---> 94   raise TypeError(f"{k} is not a valid argument, kwargs should be empty "
#      95                   " for `optimizer_experimental.Optimizer`.")
#
# TypeError: weight_decay is not a valid argument, kwargs should be empty  for `optimizer_experimental.Optimizer`.
